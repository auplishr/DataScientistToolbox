# %% [markdown]
# ### Capstone Project - Telecom Network Service Disruption
# #### Build Models with FULL dataset
# #### This is Part 3 of the project documentation. (File Name 03-FINAL-TelstraModels-FullDataset)
# #### Please see Part 1 for Project Details and Executive Summary. (File Name 01-FINAL -TelstraEDA)

# %% [markdown]
# <body lang="EN-AU" style="tab-interval:36.0pt">
#
# <div class="WordSection1">
#
# <p class="MsoNormal"><span style="font-size:14.0pt;line-height:105%;font-family:
# &quot;Microsoft Sans Serif&quot;,sans-serif">Develop Models<o:p></o:p></span></p>
#
# <p class="MsoNormal"><span style="font-size:12.0pt;line-height:105%;font-family:
# &quot;Microsoft Sans Serif&quot;,sans-serif">Data<o:p></o:p></span></p>
#
# <p class="MsoListParagraphCxSpFirst" style="margin-left:49.65pt;mso-add-space:
# auto;text-indent:-18.0pt;mso-list:l0 level1 lfo2"><!--[if !supportLists]--><span style="font-family:Wingdings;mso-fareast-font-family:Wingdings;mso-bidi-font-family:
# Wingdings"><span style="mso-list:Ignore">§<span style="font:7.0pt &quot;Times New Roman&quot;">&nbsp;
# </span></span></span><!--[endif]--><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">Dependent
# variable is a <span class="GramE">3 class</span> variable <span class="SpellE"><b>fault_severity</b></span><o:p></o:p></span></p>
#
# <p class="MsoListParagraphCxSpLast" style="margin-left:49.65pt;mso-add-space:
# auto;text-indent:-18.0pt;mso-list:l0 level1 lfo2"><!--[if !supportLists]--><span style="font-family:Wingdings;mso-fareast-font-family:Wingdings;mso-bidi-font-family:
# Wingdings"><span style="mso-list:Ignore">§<span style="font:7.0pt &quot;Times New Roman&quot;">&nbsp;
# </span></span></span><!--[endif]--><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">5
# features used <span class="SpellE"><b>log_feature</b></span><b> </b>(386 classes)<b>,
# <span class="SpellE">resource_type</span> </b>(3 classes), <span class="SpellE"><b>event_type</b></span><b>
# </b>(6 classes), <br>
# <b>location </b>(32 classes), <span class="SpellE"><b>severity_type</b></span><b>
# </b>(5 classes),<o:p></o:p></span></p>
#
# <p class="MsoNormal"><span style="font-size:12.0pt;line-height:105%;font-family:
# &quot;Microsoft Sans Serif&quot;,sans-serif">Estimators<o:p></o:p></span></p>
#
# <p class="MsoListParagraph" style="margin-left:49.65pt;mso-add-space:auto;
# text-indent:-18.0pt;mso-list:l0 level1 lfo2"><!--[if !supportLists]--><span style="font-family:Wingdings;mso-fareast-font-family:Wingdings;mso-bidi-font-family:
# Wingdings"><span style="mso-list:Ignore">§<span style="font:7.0pt &quot;Times New Roman&quot;">&nbsp;
# </span></span></span><!--[endif]--><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">5
# classifier estimators have been selected for comparison – <span class="SpellE">RandomForest</span>
# Classifier, <span class="SpellE">KNeighbors</span> Classifier, <br>
# <span class="SpellE">DecisionTress</span> Classifier, AdaBoost <span class="SpellE">Classfier</span>, <span class="SpellE">GradientBoostClassifer</span><o:p></o:p></span></p>
#
# <p class="MsoNormal"><span style="font-size:12.0pt;line-height:105%;font-family:
# &quot;Microsoft Sans Serif&quot;,sans-serif">Hyperparameters<o:p></o:p></span></p>
#
# <p class="MsoListParagraph" style="margin-left:49.65pt;mso-add-space:auto;
# text-indent:-18.0pt;mso-list:l0 level1 lfo2"><!--[if !supportLists]--><span style="font-family:Wingdings;mso-fareast-font-family:Wingdings;mso-bidi-font-family:
# Wingdings"><span style="mso-list:Ignore">§<span style="font:7.0pt &quot;Times New Roman&quot;">&nbsp;
# </span></span></span><!--[endif]--><i><span lang="EN-US" style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
# mso-ansi-language:EN-US">Hyperparameters for all estimators derived using <span class="SpellE"><span class="GramE">sklearn.model</span>_selection.RandomizedSearchCV</span><br>
# </span></i><span lang="EN-US" style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
# mso-ansi-language:EN-US">Please see file 02-FINAL-TelstraHyperparameters for
# details on optimization with hyperparameters</span><span style="font-family:
# &quot;Microsoft Sans Serif&quot;,sans-serif"><o:p></o:p></span></p>
#
# <p class="MsoNormal"><span style="font-size:12.0pt;line-height:105%;font-family:
# &quot;Microsoft Sans Serif&quot;,sans-serif">Scenarios<o:p></o:p></span></p>
#
# <p class="MsoListParagraphCxSpFirst" style="margin-left:49.65pt;mso-add-space:
# auto;text-indent:-18.0pt;mso-list:l0 level1 lfo2"><!--[if !supportLists]--><span style="font-family:Wingdings;mso-fareast-font-family:Wingdings;mso-bidi-font-family:
# Wingdings"><span style="mso-list:Ignore">§<span style="font:7.0pt &quot;Times New Roman&quot;">&nbsp;
# </span></span></span><!--[endif]--><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">Each
# estimator was run for the following scenarios<o:p></o:p></span></p>
#
# <p class="MsoListParagraphCxSpMiddle" style="margin-left:49.65pt;mso-add-space:
# auto;text-indent:-18.0pt;mso-list:l0 level1 lfo2"><!--[if !supportLists]--><span style="font-family:Wingdings;mso-fareast-font-family:Wingdings;mso-bidi-font-family:
# Wingdings"><span style="mso-list:Ignore">§<span style="font:7.0pt &quot;Times New Roman&quot;">&nbsp;
# </span></span></span><!--[endif]--><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">All
# features used – hyperparameters given<o:p></o:p></span></p>
#
# <p class="MsoListParagraphCxSpLast" style="margin-left:49.65pt;mso-add-space:
# auto;text-indent:-18.0pt;mso-list:l0 level1 lfo2"><!--[if !supportLists]--><span style="font-family:Wingdings;mso-fareast-font-family:Wingdings;mso-bidi-font-family:
# Wingdings"><span style="mso-list:Ignore">§<span style="font:7.0pt &quot;Times New Roman&quot;">&nbsp;
# </span></span></span><!--[endif]--><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">All
# features used – default hyperparameters<o:p></o:p></span></p>
#
# <p class="MsoNormal"><span style="font-size:12.0pt;line-height:105%;font-family:
# &quot;Microsoft Sans Serif&quot;,sans-serif">Results<o:p></o:p></span></p>
#
# <table class="MsoNormalTable" border="0" cellspacing="0" cellpadding="0" width="510" style="width:382.7pt;margin-left:13.8pt;border-collapse:collapse;mso-yfti-tbllook:
#  1184;mso-padding-alt:0cm 5.4pt 0cm 5.4pt">
#  <tbody><tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes;height:30.75pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   mso-border-alt:solid windowtext .5pt;padding:0cm 5.4pt 0cm 5.4pt;height:30.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">Estimator<o:p></o:p></span></p>
#   </td>
#   <td width="151" nowrap="" colspan="2" valign="bottom" style="width:4.0cm;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:30.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">All features<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:30.75pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="151" colspan="2" valign="bottom" style="width:4.0cm;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:30.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">Features except <span class="SpellE">logfeature</span><o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:1;height:36.75pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:36.75pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="76" valign="bottom" style="width:2.0cm;border-top:none;border-left:
#   none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:36.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">Default params<o:p></o:p></span></p>
#   </td>
#   <td width="76" valign="bottom" style="width:2.0cm;border-top:none;border-left:
#   none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:36.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">Optimum params<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:36.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" valign="bottom" style="width:49.65pt;border-top:none;border-left:
#   none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:36.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">Default params<o:p></o:p></span></p>
#   </td>
#   <td width="85" valign="bottom" style="width:63.75pt;border-top:none;border-left:
#   none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:36.75pt">
#   <p class="MsoNormal" align="center" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:center;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">Optimum params<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:2;height:15.0pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">Random Forest <span class="SpellE">Classifer</span><o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">72.28%<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">75.49%<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" nowrap="" valign="bottom" style="width:49.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">59.95%<o:p></o:p></span></p>
#   </td>
#   <td width="85" nowrap="" valign="bottom" style="width:63.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">62.53%<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:3;height:15.0pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="mso-bidi-font-size:11.0pt;font-family:
#   &quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">KNeigbors</span></span><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU"> <span class="SpellE">Classifer</span><o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">71.33%<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">73.81%<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" nowrap="" valign="bottom" style="width:49.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">59.37%<o:p></o:p></span></p>
#   </td>
#   <td width="85" nowrap="" valign="bottom" style="width:63.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">63.66%<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:4;height:15.0pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="mso-bidi-font-size:11.0pt;font-family:
#   &quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">DecisionTree</span></span><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU"> <span class="SpellE">Classifer</span> <o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">71.38%<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">70.11%<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" nowrap="" valign="bottom" style="width:49.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">58.83%<o:p></o:p></span></p>
#   </td>
#   <td width="85" nowrap="" valign="bottom" style="width:63.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">58.19%<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:5;height:15.0pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">AdaBoost <span class="SpellE">Classifer</span><o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">72.42%<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">73.81%<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" nowrap="" valign="bottom" style="width:49.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">66.23%<o:p></o:p></span></p>
#   </td>
#   <td width="85" nowrap="" valign="bottom" style="width:63.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">65.73%<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:6;height:15.0pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="mso-bidi-font-size:11.0pt;font-family:
#   &quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">GradientBoost</span></span><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU"> <span class="SpellE">Classifer</span><o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">76.16%<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">76.48%<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" nowrap="" valign="bottom" style="width:49.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">66.41%<o:p></o:p></span></p>
#   </td>
#   <td width="85" nowrap="" valign="bottom" style="width:63.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">65.96%<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:7;height:15.0pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" style="width:2.0cm;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Courier New&quot;;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" nowrap="" valign="bottom" style="width:49.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="85" nowrap="" valign="bottom" style="width:63.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:8;mso-yfti-lastrow:yes;height:15.0pt">
#   <td width="189" nowrap="" valign="bottom" style="width:5.0cm;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">Baseline Accuracy<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" valign="bottom" style="width:2.0cm;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="mso-bidi-font-size:11.0pt;
#   font-family:&quot;Microsoft Sans Serif&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">64.82%<o:p></o:p></span></p>
#   </td>
#   <td width="76" nowrap="" style="width:2.0cm;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;font-family:&quot;Courier New&quot;;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="66" nowrap="" valign="bottom" style="width:49.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="85" nowrap="" valign="bottom" style="width:63.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:15.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="mso-bidi-font-size:11.0pt;mso-ascii-font-family:Calibri;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;mso-hansi-font-family:Calibri;
#   mso-bidi-font-family:Calibri;color:black;mso-fareast-language:EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#  </tr>
# </tbody></table>
#
# <p class="MsoListParagraphCxSpFirst" style="margin-left:0cm;mso-add-space:auto"><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif"><o:p>&nbsp;</o:p></span></p>
#
# <p class="MsoListParagraphCxSpMiddle" style="margin-left:0cm;mso-add-space:auto"><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">As can be seen, there is
# an improvement in accuracy, across all estimators except <span class="SpellE">DecisionTree</span>,
# when<br>
# hyperparameters are provided to the model.<o:p></o:p></span></p>
#
# <p class="MsoListParagraphCxSpMiddle" style="margin-left:0cm;mso-add-space:auto"><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif"><o:p>&nbsp;</o:p></span></p>
#
# <p class="MsoListParagraphCxSpLast" style="margin-left:0cm;mso-add-space:auto"><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif">Top 20 features by
# Estimator<o:p></o:p></span></p>
#
# <table class="MsoNormalTable" border="0" cellspacing="0" cellpadding="0" width="680" style="width:18.0cm;margin-left:-.4pt;border-collapse:collapse;mso-yfti-tbllook:
#  1184;mso-padding-alt:0cm 5.4pt 0cm 5.4pt">
#  <tbody><tr style="mso-yfti-irow:0;mso-yfti-firstrow:yes;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   mso-border-alt:solid windowtext .5pt;padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><b><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">Random Forest<o:p></o:p></span></b></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" valign="bottom" style="width:83.5pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><b><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">Decision Tree<o:p></o:p></span></b></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" valign="bottom" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><b><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">AdaBoost<o:p></o:p></span></b></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" valign="bottom" style="width:72.15pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><b><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">GradientBoost</span></b></span><b><span style="font-size:9.0pt;
#   font-family:&quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></b></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border:solid windowtext 1.0pt;
#   border-left:none;mso-border-top-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:1;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature203<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.117975<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature203<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.196701<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature203<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.1<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature203<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.124773<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:2;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature82<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.083862<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">severity_type_1<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.058009<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature170<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.06<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature170<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.034011<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:3;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature170<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.03621<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature82<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.050477<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">resource_type_RT8<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.06<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature202<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.03206<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:4;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature54<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.033386<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature170<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.044608<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_OTH</span></span><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.04<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature209<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.024589<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:5;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature232<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.027159<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature54<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02519<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature202<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.04<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature232<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.024231<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:6;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature312<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.022933<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature312<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.024538<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">location_995<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature312<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.023538<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:7;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_OTH</span></span><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.022118<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature80<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.022101<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">location_OTH</span></span><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature73<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.023496<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:8;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature80<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.021604<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature68<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.019273<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_ET11<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature82<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.018607<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:9;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature68<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.020152<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature232<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.017752<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_ET34<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature171<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.018412<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:10;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature71<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.018804<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">resource_type_OTH</span></span><span style="font-size:9.0pt;
#   font-family:&quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.015536<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_ET35<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature155<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.016335<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:11;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">location_OTH</span></span><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.016184<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_OTH</span></span><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.014884<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">severity_type_1<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature179<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.016276<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:12;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_ET15<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.016145<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature73<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.014877<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature193<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">severity_type_1<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.014595<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:13;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_ET34<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.015661<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature71<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.013795<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature195<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature134<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.01443<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:14;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">severity_type_1<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.015401<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature171<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.012685<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature196<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature315<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.014178<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:15;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature313<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.014771<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature315<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.012159<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature205<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature70<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.014025<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:16;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature201<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.014159<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature193<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.011945<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature140<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature368<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.013464<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:17;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature193<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.013333<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature201<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.011271<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature209<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature227<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.012689<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:18;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">severity_type_2<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.012206<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature291<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.011234<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature212<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature314<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.012604<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:19;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature73<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.011528<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_ET11<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.009957<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature319<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature54<o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.012336<o:p></o:p></span></p>
#   </td>
#  </tr>
#  <tr style="mso-yfti-irow:20;mso-yfti-lastrow:yes;height:12.0pt">
#   <td width="109" nowrap="" style="width:81.4pt;border:solid windowtext 1.0pt;
#   border-top:none;mso-border-left-alt:solid windowtext .5pt;mso-border-bottom-alt:
#   solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;padding:
#   0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">resource_type_RT8<o:p></o:p></span></p>
#   </td>
#   <td width="60" nowrap="" valign="bottom" style="width:44.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.011016<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="111" nowrap="" style="width:83.5pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_ET15<o:p></o:p></span></p>
#   </td>
#   <td width="62" nowrap="" valign="bottom" style="width:46.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.00971<o:p></o:p></span></p>
#   </td>
#   <td width="19" nowrap="" valign="bottom" style="width:14.15pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="109" nowrap="" style="width:81.4pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">log_feature295<o:p></o:p></span></p>
#   </td>
#   <td width="36" nowrap="" valign="bottom" style="width:26.65pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.02<o:p></o:p></span></p>
#   </td>
#   <td width="17" nowrap="" valign="bottom" style="width:12.85pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">&nbsp;<o:p></o:p></span></p>
#   </td>
#   <td width="96" nowrap="" style="width:72.15pt;border-top:none;border-left:none;
#   border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" style="margin-bottom:0cm;margin-bottom:.0001pt;line-height:
#   normal"><span class="SpellE"><span style="font-size:9.0pt;font-family:&quot;Calibri Light&quot;,sans-serif;
#   mso-fareast-font-family:&quot;Times New Roman&quot;;color:black;mso-fareast-language:
#   EN-AU">event_type_OTH</span></span><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU"><o:p></o:p></span></p>
#   </td>
#   <td width="45" nowrap="" valign="bottom" style="width:33.75pt;border-top:none;
#   border-left:none;border-bottom:solid windowtext 1.0pt;border-right:solid windowtext 1.0pt;
#   mso-border-bottom-alt:solid windowtext .5pt;mso-border-right-alt:solid windowtext .5pt;
#   padding:0cm 5.4pt 0cm 5.4pt;height:12.0pt">
#   <p class="MsoNormal" align="right" style="margin-bottom:0cm;margin-bottom:.0001pt;
#   text-align:right;line-height:normal"><span style="font-size:9.0pt;font-family:
#   &quot;Calibri Light&quot;,sans-serif;mso-fareast-font-family:&quot;Times New Roman&quot;;
#   color:black;mso-fareast-language:EN-AU">0.012102<o:p></o:p></span></p>
#   </td>
#  </tr>
# </tbody></table>
#
# <p class="MsoListParagraph" style="margin-left:0cm;mso-add-space:auto"><span style="font-family:&quot;Microsoft Sans Serif&quot;,sans-serif"><o:p>&nbsp;</o:p></span></p>
#
# </div>
#
#
#
#
# </body>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import time

# %% [markdown]
# ### Load Data

# %%
# Full dataset
train_id = pd.read_csv('./Data/train_id.csv')
test_id = pd.read_csv('./Data/test_id.csv')

# %%
print('Dataframe train - number of rows columns', train_id.shape)
print('Dataframe test - number of rows columns', test_id.shape)
# Out:
# Dataframe train - number of rows columns (7381, 434)
# Dataframe test - number of rows columns (11171, 434)

# %% [markdown]
# ### Develop Models

# %%
#################################
# Import classifier model modules
#################################
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC
#Gridsearch and scoring
from sklearn.grid_search import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

# %%
#################################
# Prepare data for modelling
#################################
# Create target dataframe
target = train_id['fault_severity']
# Drop fault_severity from train so we don't have to specify column names
train_id.drop(['fault_severity'], axis=1, inplace=True)
test_id.drop(['fault_severity'], axis=1, inplace=True)
train_id.drop(['id'], axis=1, inplace=True)
test_id.drop(['id'], axis=1, inplace=True)

# %%
#################################
# Assign values to lists
#################################
XTrain = train_id
yTrain = target
XTest = test_id
# Split training dataset into "train" and "validate" to compare model accuracy
X_train, X_test, y_train, y_test = train_test_split(XTrain,yTrain, test_size=0.3, random_state=101)

# %%
#################################
# Baseline accuracy on the percentage for largest class in training dataset
#################################
baseline = target.value_counts()/len(target)
print('Baseline accuracy', round(baseline[0]*100,2))
# Out:
# Baseline accuracy 64.82

# %%
#############################################################
# Run models on "train" and "test" and get relative scores
#############################################################
# Random Forest Classifer with params
###
model = RandomForestClassifier(bootstrap=False,max_depth=70,max_features='auto',min_samples_leaf=2,min_samples_split=2,\
                              n_estimators=1200)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
x = model.feature_importances_
print ('Random Forest Classifer accuracy - params:',round(accuracy_score(y_test, y_pred),4))
###
# Random Forest Classifer default
###
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print ('Random Forest Classifer accuracy - default:',round(accuracy_score(y_test, y_pred),4))
###
# Model feature importance
###
x = model.feature_importances_
zRF = pd.Series(data=x,index=X_train.columns)
print('Top 20 features')
print(zRF.sort_values(ascending=False).head(20))
# Out:
# Random Forest Classifer accuracy - params: 0.7549
# Random Forest Classifer accuracy - default: 0.7228
# Top 20 features
# log_feature203       0.117975
# log_feature82        0.083862
# log_feature170       0.036210
# log_feature54        0.033386
# log_feature232       0.027159
# log_feature312       0.022933
# event_type_OTH       0.022118
# log_feature80        0.021604
# log_feature68        0.020152
# log_feature71        0.018804
# location_OTH         0.016184
# event_type_ET15      0.016145
# event_type_ET34      0.015661
# severity_type_1      0.015401
# log_feature313       0.014771
# log_feature201       0.014159
# log_feature193       0.013333
# severity_type_2      0.012206
# log_feature73        0.011528
# resource_type_RT8    0.011016
# dtype: float64

# %%
###
# KNeighbors Classifier params
###
model = KNeighborsClassifier(algorithm='kd_tree',metric='minkowski',leaf_size=10,p=4,weights='uniform',n_neighbors=20)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print ('KNeighbors Classifer accuracy - params:',round(accuracy_score(y_test, y_pred),4))
###
# KNeighbors Classifier params default
###
model = KNeighborsClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print ('KNeighbors Classifer accuracy - default:',round(accuracy_score(y_test, y_pred),4))
###
# Model feature importance not available in KNN
###
# Out:
# KNeighbors Classifer accuracy - params: 0.7381
# KNeighbors Classifer accuracy - default: 0.7133

# %%
###
# DecisionTree Classifier params
###
model = DecisionTreeClassifier(class_weight='balanced',criterion='gini',max_features=None,splitter='random')
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print ('DecisionTree Classifer accuracy - params:',round(accuracy_score(y_test, y_pred),4))
###
# DecisionTree Classifier default
###
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print ('DecisionTree Classifer accuracy - default:',round(accuracy_score(y_test, y_pred),4))
###
# Model feature importance
###
x = model.feature_importances_
zDT = pd.Series(data=x,index=X_train.columns)
print('Top 20 features')
print(zDT.sort_values(ascending=False).head(20))
# Out:
# DecisionTree Classifer accuracy - params: 0.7011
# DecisionTree Classifer accuracy - default: 0.7138
# Top 20 features
# log_feature203       0.196701
# severity_type_1      0.058009
# log_feature82        0.050477
# log_feature170       0.044608
# log_feature54        0.025190
# log_feature312       0.024538
# log_feature80        0.022101
# log_feature68        0.019273
# log_feature232       0.017752
# resource_type_OTH    0.015536
# event_type_OTH       0.014884
# log_feature73        0.014877
# log_feature71        0.013795
# log_feature171       0.012685
# log_feature315       0.012159
# log_feature193       0.011945
# log_feature201       0.011271
# log_feature291       0.011234
# event_type_ET11      0.009957
# event_type_ET15      0.009710
# dtype: float64

# %%
###
# AdaBoost Classifier params
###
model = AdaBoostClassifier(algorithm='SAMME.R',learning_rate=1.0,n_estimators=90,random_state=88,base_estimator=None)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print ('AdaBoost Classifer accuracy - params:',round(accuracy_score(y_test, y_pred),4))
###
# AdaBoost Classifier default
###
model = AdaBoostClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print ('AdaBoost Classifer accuracy - default:',round(accuracy_score(y_test, y_pred),4))
###
# Model feature importance
###
x = model.feature_importances_
zAB = pd.Series(data=x,index=X_train.columns)
print('Top 20 features')
print(zAB.sort_values(ascending=False).head(20))
# Out:
# AdaBoost Classifer accuracy - params: 0.7381
# AdaBoost Classifer accuracy - default: 0.7242
# Top 20 features
# log_feature203       0.10
# log_feature170       0.06
# resource_type_RT8    0.06
# event_type_OTH       0.04
# log_feature202       0.04
# location_995         0.02
# location_OTH         0.02
# event_type_ET11      0.02
# event_type_ET34      0.02
# event_type_ET35      0.02
# severity_type_1      0.02
# log_feature193       0.02
# log_feature195       0.02
# log_feature196       0.02
# log_feature205       0.02
# log_feature140       0.02
# log_feature209       0.02
# log_feature212       0.02
# log_feature319       0.02
# log_feature295       0.02
# dtype: float64

# %%
###
# GradientBoost Classifier params
###
model = GradientBoostingClassifier(criterion='friedman_mse',init=None,learning_rate=0.1,max_depth=5,max_features='auto',\
                                  n_estimators=150,random_state=88)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print ('GradientBoost Classifer accuracy - params:',round(accuracy_score(y_test, y_pred),4))
###
# GradientBoost Classifier params
###
model = GradientBoostingClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
print ('GradientBoost Classifer accuracy - default:',round(accuracy_score(y_test, y_pred),4))
###
# Model feature importance
###
x = model.feature_importances_
zGB = pd.Series(data=x,index=X_train.columns)
print('Top 20 features')
print(zGB.sort_values(ascending=False).head(20))
# Out:
# GradientBoost Classifer accuracy - params: 0.7616
# GradientBoost Classifer accuracy - default: 0.7648
# Top 20 features
# log_feature203     0.124773
# log_feature170     0.034011
# log_feature202     0.032060
# log_feature209     0.024589
# log_feature232     0.024231
# log_feature312     0.023538
# log_feature73      0.023496
# log_feature82      0.018607
# log_feature171     0.018412
# log_feature155     0.016335
# log_feature179     0.016276
# severity_type_1    0.014595
# log_feature134     0.014430
# log_feature315     0.014178
# log_feature70      0.014025
# log_feature368     0.013464
# log_feature227     0.012689
# log_feature314     0.012604
# log_feature54      0.012336
# event_type_OTH     0.012102
# dtype: float64

# %%
X_test['log_feature203'][X_test.log_feature203 > 0].count()
# Out:
# 337

# %%
X_test['log_feature170'][X_test.log_feature170 > 0].count()
# Out:
# 177

# %%
X_test['log_feature82'][X_test.log_feature82 > 0].count()
# Out:
# 410
